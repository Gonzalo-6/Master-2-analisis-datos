# %% [markdown]
# # Operaciones de comparación

# %%
d = np.random.randint(1,20, (4,5))
d
# Out:
# array([[15, 19,  3,  4, 17],
#        [ 2, 19, 12, 13,  4],
#        [ 3, 15,  9, 12,  4],
#        [12,  5,  4, 17,  6]], dtype=int32)

# %%
np.any(d > 10)
# Out:
# np.True_

# %%
np.any(d > 20)
# Out:
# np.False_

# %%
np.any(d > 10, axis = 0)
# Out:
# array([ True,  True,  True,  True,  True])

# %%
np.any(d < 2 , axis = 1 )
# Out:
# array([False, False, False, False])

# %%
np.all(d > 10)
# Out:
# np.False_

# %%
np.all(d > 10, axis = 0)
# Out:
# array([False, False, False, False, False])

# %%
np.all(d > 10, axis = 1)
# Out:
# array([False, False, False, False])

# %%
np.any(d < 2 , axis = 1 )
# Out:
# array([False, False, False, False])

# %%
import numpy as np
